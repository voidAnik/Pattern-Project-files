# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/Pattern\ Lab/Datasets/Datasets\ SL/ENAC/npy
path = "/content/drive/My Drive/Pattern Lab/Datasets/Datasets SL"
# Out:
# /content/drive/My Drive/Pattern Lab/Datasets/Datasets SL/ENAC/npy

# %%
import pandas as pd
npy = np.load("PD_train_special_ENAC10.npy",allow_pickle=True)
print(npy)
